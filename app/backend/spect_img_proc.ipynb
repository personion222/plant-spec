# %%
import cv2
import numpy
import glob
from matplotlib import pyplot
# %matplotlib inline

# %%
pref = "../../openmvcam-firmware/spect_imgs/473385721*"
csvdirs = glob.glob(pref)
print(csvdirs)
csvs = [numpy.loadtxt(csvdir, delimiter=',') for csvdir in csvdirs]
for img in csvs:
    img[1::2] = img[1::2, ::-1]
# Out:
# ['../../openmvcam-firmware/spect_imgs/473385721A.csv', '../../openmvcam-firmware/spect_imgs/473385721B.csv', '../../openmvcam-firmware/spect_imgs/473385721C.csv', '../../openmvcam-firmware/spect_imgs/473385721D.csv', '../../openmvcam-firmware/spect_imgs/473385721E.csv', '../../openmvcam-firmware/spect_imgs/473385721F.csv', '../../openmvcam-firmware/spect_imgs/473385721G.csv', '../../openmvcam-firmware/spect_imgs/473385721H.csv', '../../openmvcam-firmware/spect_imgs/473385721I.csv', '../../openmvcam-firmware/spect_imgs/473385721J.csv', '../../openmvcam-firmware/spect_imgs/473385721K.csv', '../../openmvcam-firmware/spect_imgs/473385721L.csv', '../../openmvcam-firmware/spect_imgs/473385721R.csv', '../../openmvcam-firmware/spect_imgs/473385721S.csv', '../../openmvcam-firmware/spect_imgs/473385721T.csv', '../../openmvcam-firmware/spect_imgs/473385721U.csv', '../../openmvcam-firmware/spect_imgs/473385721V.csv', '../../openmvcam-firmware/spect_imgs/473385721W.csv']

# %%
totalmax = max(numpy.max(img) for img in csvs)
for img in csvs:
    if totalmax != 0:
        imgnorm = (img * (255 / totalmax)).astype(numpy.uint8)
    else:
        print("caught 0 division")
        imgnorm = img.astype(numpy.uint8)
    imgnorm = cv2.rotate(imgnorm, cv2.ROTATE_90_CLOCKWISE)
    # cv2.imshow('', imgnorm)
    # cv2.waitKey(0)
    # cv2.destroyAllWindows()
    pyplot.imshow(imgnorm)
    pyplot.show()
